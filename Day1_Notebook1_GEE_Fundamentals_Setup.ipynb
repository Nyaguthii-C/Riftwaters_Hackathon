# %% [markdown]
# ## 1. Environment Setup
#
# Run the cell below. On first run this opens a browser window/tab for authentication — sign in with the Google account that was added to the shared training project.
#
# **If you get a permission error on `Initialize`**: Flag it immediately rather than debugging — it's a project-access issue, not a code issue.

# %%
import ee
import geemap

# Swap this for the shared training project ID given in the setup slides
PROJECT_ID = "riftwaters-505207"

ee.Authenticate()
ee.Initialize(project=PROJECT_ID)

print("✅ Earth Engine initialized")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Earth Engine initialized

# %% [markdown]
# ## 2. Geometries
#
# `ee.Geometry` defines *where* — every acquisition and filter operation needs one. Common constructors: `ee.Geometry.Point`, `ee.Geometry.Polygon`, `ee.Geometry.Rectangle`.
#
# Below is the **shared training ROI** (Lake Naivasha) and date range. Copy this cell as-is into every notebook this week.

# %%
# --- Shared training config: reuse this cell in every notebook ---
ROI = ee.Geometry.Polygon([
            [36.244378206729166,-0.838827881647561],
            [36.442132112979166,-0.838827881647561],
            [36.442132112979166,-0.6664947946163098],
            [36.244378206729166,-0.6664947946163098],
            [36.244378206729166,-0.838827881647561]
        ])

START_DATE = "2026-01-01"
END_DATE = "2026-02-28"
REGION_NAME = "naivasha"

area = ROI.area().divide(1e6).getInfo()
print("ROI area (km²):", area)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ROI area (km²): 421.3349221720713

# %% [markdown]
# ## 3. ImageCollection vs Image, and filtering
#
# - `ee.Image`: a single satellite image.
# - `ee.ImageCollection`: a stack of images.

# %%
# An example of an Image collection
s2_collection = (
    ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
    .filterBounds(ROI)
    .filterDate(START_DATE, END_DATE)
    .filter(ee.Filter.lte("CLOUDY_PIXEL_PERCENTAGE", 30))
)

count = s2_collection.size().getInfo()

s2_images = s2_collection.aggregate_array('system:index').getInfo() #This will return a list of all the scene indices in the collection
print(f"Found {count} Sentinel-2 scenes over Naivasha, {START_DATE} → {END_DATE}")
print(f"Scenes: {s2_images}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Found 18 Sentinel-2 scenes over Naivasha, 2026-01-01 → 2026-02-28
# Scenes: ['20260102T074331_20260102T075113_T36MZE', '20260102T074331_20260102T075113_T37MBV', '20260104T075451_20260104T075453_T36MZE', '20260104T075451_20260104T075453_T37MBV', '20260107T074219_20260107T075705_T36MZE', '20260107T074219_20260107T075705_T37MBV', '20260112T074301_20260112T075053_T36MZE', '20260122T074221_20260122T075014_T36MZE', '20260122T074221_20260122T075014_T37MBV', '20260127T074059_20260127T075449_T36MZE', '20260127T074059_20260127T075449_T37MBV', '20260201T074131_20260201T075002_T37MBV', '20260206T074009_20260206T075427_T36MZE', '20260206T074009_20260206T075427_T37MBV', '20260211T074041_20260211T075001_T36MZE', '20260211T074041_20260211T075001_T37MBV', '20260216T073909_20260216T075710_T36MZE', '20260216T073909_20260216T075710_T37MBV']

# %%
# Inspect one image by printing the available bands
first_image = s2_collection.first()
print("Bands:", first_image.bandNames().getInfo())
print("Date:", ee.Date(first_image.get('system:time_start')).format('YYYY-MM-dd').getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Bands: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B8A', 'B9', 'B11', 'B12', 'AOT', 'WVP', 'SCL', 'TCI_R', 'TCI_G', 'TCI_B', 'MSK_CLDPRB', 'MSK_SNWPRB', 'QA10', 'QA20', 'QA60', 'MSK_CLASSI_OPAQUE', 'MSK_CLASSI_CIRRUS', 'MSK_CLASSI_SNOW_ICE']
# Date: 2026-01-02

# %% [markdown]
# ## 4. Visualizing with geemap
#
# `geemap` gives us an interactive map inside the notebook so we can sanity-check what we've filtered before doing any export or processing. This is the fastest way to catch a wrong ROI or empty collection.

# %%
composite = s2_collection.median().clip(ROI)

vis_params = {
    "bands": ["B4", "B3", "B2"],  # true color
    "min": 0,
    "max": 3000,
}

Map = geemap.Map()
Map.centerObject(ROI, 12)
Map.addLayer(composite, vis_params, "S2 median composite")
Map.addLayer(ROI, {"color": "red"}, "Training ROI", opacity=0.3)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-0.7526618913033527, 36.343255159855566], controls=(WidgetControl(options=['position', 'transparen…

# %% [markdown]
# Now lets select 1 scene from the scenes in the image collection

# %%
#Try images from 0-17 to see the difference (0-17 are the indices of the images in the collection)
scene = s2_collection.filter(ee.Filter.eq('system:index', s2_images[6]))
Map = geemap.Map()
Map.centerObject(ROI, 10)
Map.addLayer(scene, {"bands": ["B4", "B3", "B2"], "min": 0, "max": 1000}, "scene")
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-0.7526618913033527, 36.343255159855566], controls=(WidgetControl(options=['position', 'transparen…

# %%
#An example of an ee.Image image
s2_image = ee.Image("20260102T074331_20260102T075113_T36MZE")
Map = geemap.Map()
Map.centerObject(ROI, 10)
Map.addLayer(s2_image, {"bands": ["B4", "B3", "B2"], "min": 0, "max": 1000}, "s2_image")
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     358   try:
# --> 359     return call.execute(num_retries=num_retries)
#     360   except googleapiclient.errors.HttpError as e:
#
# /usr/local/lib/python3.12/dist-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#
# /usr/local/lib/python3.12/dist-packages/googleapiclient/http.py in execute(self, http, num_retries)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1/projects/riftwaters-505207/maps?fields=name&alt=json returned "Image.load: Image asset '20260102T074331_20260102T075113_T36MZE' not found (does not exist or caller does not have access).". Details: "Image.load: Image asset '20260102T074331_20260102T075113_T36MZE' not found (does not exist or caller does not have access).">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# /tmp/ipykernel_1608/3433938206.py in <cell line: 0>()
#       3 Map = geemap.Map()
#       4 Map.centerObject(ROI, 10)
# ----> 5 Map.addLayer(s2_image, {"bands": ["B4", "B3", "B2"], "min": 0, "max": 1000}, "s2_image")
#       6 Map
#
# /usr/local/lib/python3.12/dist-packages/geemap/geemap.py in add_ee_layer(self, ee_object, vis_params, name, shown, opacity)
#     387                     )
#     388
# --> 389         super().add_layer(ee_object, vis_params, name, shown, opacity)
#     390
#     391         if isinstance(ee_object, (ee.Image, ee.ImageCollection)):
#
# /usr/local/lib/python3.12/dist-packages/geemap/core.py in add_layer(self, ee_object, vis_params, name, shown, opacity)
#    1105         if isinstance(ee_object, ee.ImageCollection):
#    1106             ee_object = ee_object.mosaic()
# -> 1107         tile_layer = ee_tile_layers.EELeafletTileLayer(
#    1108             ee_object, vis_params, name, shown, opacity
#    1109         )
#
# /usr/local/lib/python3.12/dist-packages/geemap/ee_tile_layers.py in __init__(self, ee_object, vis_params, name, shown, opacity, **kwargs)
#     190         """
#     191         self._ee_object = ee_object
# --> 192         self.url_format = _get_tile_url_format(
#     193             ee_object, _validate_vis_params(vis_params)
#     194         )
#
# /usr/local/lib/python3.12/dist-packages/geemap/ee_tile_layers.py in _get_tile_url_format(ee_object, vis_params)
#      30     """
#      31     image = _ee_object_to_image(ee_object, vis_params)
# ---> 32     map_id_dict = ee.Image(image).getMapId(vis_params)
#      33     return map_id_dict["tile_fetcher"].url_format
#      34
#
# /usr/local/lib/python3.12/dist-packages/ee/image.py in getMapId(self, vis_params)
#     152     vis_image, request = self._apply_visualization(vis_params)
#     153     request['image'] = vis_image
# --> 154     response = data.getMapId(request)
#     155     response['image'] = self
#     156     return response
#
# /usr/local/lib/python3.12/dist-packages/ee/data.py in getMapId(params)
#     697   }
#     698   _maybe_populate_workload_tag(queryParams)
# --> 699   result = _execute_cloud_call(
#     700       _get_cloud_projects()
#     701       .maps()
#
# /usr/local/lib/python3.12/dist-packages/ee/data.py in _execute_cloud_call(call, num_retries)
#     359     return call.execute(num_retries=num_retries)
#     360   except googleapiclient.errors.HttpError as e:
# --> 361     raise _translate_cloud_exception(e)  # pylint: disable=raise-missing-from
#     362
#     363
#
# EEException: Image.load: Image asset '20260102T074331_20260102T075113_T36MZE' not found (does not exist or caller does not have access).

# %% [markdown]
# ## Exercise 1.1
#
# Using the pattern above:
#
# 1. Pick a **different lake** from the list below and build its ROI (coordinates given).
# 2. Filter the Sentinel-2 collection over that ROI for the **same date range** (`START_DATE`/`END_DATE`).
# 3. Print how many scenes were found.
# 4. Display a true-color composite on a `geemap.Map()`.
#
# ```python
# # Nakuru ROI, for reference
# NAKURU_ROI = ee.Geometry.Polygon([
#     [36.045150257654164, -0.41882934935973415],
#     [36.13441417366979, -0.41882934935973415],
#     [36.13441417366979, -0.29935539913088666],
#     [36.045150257654164, -0.29935539913088666],
#     [36.045150257654164, -0.41882934935973415],
# ])
#
# ELEMENTAITA_ROI = ee.Geometry.Polygon([
#             [36.20503005704847,-0.4844042871968538],
#             [36.27541122159925,-0.4844042871968538],
#             [36.27541122159925,-0.3992627836576272],
#             [36.20503005704847,-0.3992627836576272],
#             [36.20503005704847,-0.4844042871968538]
#         ])
# BARINGO_ROI = ee.Geometry.Polygon([
#             [35.98987673288601,0.4361077040885743],
#             [36.180764184057885,0.4361077040885743],
#             [36.180764184057885,0.7574399496732773],
#             [35.98987673288601,0.7574399496732773],
#             [35.98987673288601,0.4361077040885743]
#         ])
#
# ```
#
# Try to do it without re-reading the cells above — you'll need this exact filter → count → visualize pattern constantly for the rest of the week.

# %%
# Your solution here
BARINGO_ROI = ee.Geometry.Polygon([
             [35.98987673288601,0.4361077040885743],
             [36.180764184057885,0.4361077040885743],
             [36.180764184057885,0.7574399496732773],
             [35.98987673288601,0.7574399496732773],
             [35.98987673288601,0.4361077040885743]
         ])

# ELEMENTAITA_ROI = ee.Geometry.Polygon([
#             [36.20503005704847,-0.4844042871968538],
#             [36.27541122159925,-0.4844042871968538],
#             [36.27541122159925,-0.3992627836576272],
#             [36.20503005704847,-0.3992627836576272],
#             [36.20503005704847,-0.4844042871968538]
#         ])
START_DATE = "2025-01-01"
END_DATE = "2025-02-28"
REGION_NAME = "BARINGO"

s2_collection = (
    ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED")
    .filterBounds(BARINGO_ROI)
    .filterDate(START_DATE, END_DATE)
    .filter(ee.Filter.lte("CLOUDY_PIXEL_PERCENTAGE", 30))
)

count = s2_collection.size().getInfo()

s2_images = s2_collection.aggregate_array('system:index').getInfo()

print(f"Found {count} Sentinel-2 scenes over Baringo, {START_DATE} → {END_DATE}")
print(f"Scenes: {s2_images}")

composite = s2_collection.median().clip(BARINGO_ROI)

vis_params = {
    "bands": ["B4", "B3", "B2"],  # true color
    "min": 0,
    "max": 3000,
}

Map = geemap.Map()
Map.centerObject(BARINGO_ROI, 12)
Map.addLayer(composite, vis_params, "S2 median composite")
Map.addLayer(BARINGO_ROI, {"color": "red"}, "Training ROI", opacity=0.3)
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Found 9 Sentinel-2 scenes over Baringo, 2025-01-01 → 2025-02-28
# Scenes: ['20250105T075229_20250105T080453_T36NZF', '20250110T075311_20250110T075949_T36NZF', '20250120T075231_20250120T080500_T36NZF', '20250125T075119_20250125T080451_T36NZF', '20250204T075029_20250204T080452_T36NZF', '20250209T075121_20250209T080331_T36NZF', '20250214T074929_20250214T080453_T36NZF', '20250219T075011_20250219T080326_T36NZF', '20250224T074819_20250224T080453_T36NZF']
# Map(center=[0.596773090548779, 36.08532045847298], controls=(WidgetControl(options=['position', 'transparent_b…
